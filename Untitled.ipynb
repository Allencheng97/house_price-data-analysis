# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
records = pd.read_csv('data-utf8.csv')

# %%
df = pd.DataFrame(records)

# %%
data=records[['total_price','area']]
data=np.array(data)

# %%
data
# Out:
# array([[1.500e+05, 3.600e+01],
#        [3.680e+05, 7.200e+01],
#        [3.300e+05, 9.467e+01],
#        ...,
#        [1.200e+06, 1.950e+02],
#        [4.680e+05, 9.300e+01],
#        [4.800e+05, 8.730e+01]])

# %%
model=KMeans(n_clusters=3,init='random',n_init=20)

# %%
model.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300, n_clusters=3,
#        n_init=20, n_jobs=None, precompute_distances='auto', random_state=None,
#        tol=0.0001, verbose=0)

# %%
y=model.predict(data)

# %%
a=[]
b=[]
c=[]
d=[]

# %%
for i in range(len(data)):
    if y[i]==0:
        a.append(data[i,:])
        a1=np.array(a)
    if y[i]==1:
        b.append(data[i,:])
        b1=np.array(b)
    else:
        c.append(data[i,:])
        c1=np.array(c)

# %%
y
# Out:
# array([1, 1, 1, ..., 2, 1, 1])

# %%
plt.scatter(a1[:,1],a1[:,0],s=55,c='black',marker='*')

# %%
plt.scatter(b1[:,1],b1[:,0],s=55,c='red',marker='*')

# %%
plt.scatter(c1[:,1],c1[:,0],s=55,c='blue',marker='*')

# %%
plt.scatter(d1[:,1],d1[:,0],s=55,c='yellow',marker='*')

# %%
df2=pd.DataFrame(y)

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 14187  1
# 14188  1
# 14189  2
# 14190  1
# 14191  1
#
# [14192 rows x 1 columns]>

# %%
plt.scatter(data[:,1],data[:,0],s=55,c='yellow',marker='*')

# %%
fig = plt.figure(num=1)

# %%
plt.plot(a1[:,1],a1[:,0],s=55,c='black',marker='*')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-be3f3222179b> in <module>
# ----> 1 plt.plot(a1[:,1],a1[:,0],s=55,c='black',marker='*')
#
# c:\users\allen\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# c:\users\allen\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# ...

# %%
plt.plot(b1[:,1],b1[:,0],s=55,c='red',marker='.')

# %%
plt.plot(c1[:,1],c1[:,0],s=55,c='blue',marker='*')

# %%
plt.show()
